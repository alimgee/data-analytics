# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
df_corr = df.corr(method='pearson')
df_corr
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.334794           0.555939
# bill_depth_mm           -0.334794       1.000000          -0.623094
# flipper_length_mm        0.555939      -0.623094           1.000000
# body_mass_g              0.620984      -0.551199           0.887043
#
#                    body_mass_g
# bill_length_mm        0.620984
# bill_depth_mm        -0.551199
# flipper_length_mm     0.887043
# body_mass_g           1.000000

# %%
sns.set_theme(style="whitegrid")
sns.heatmap(data=df_corr, annot=True, linewidths=0.5, annot_kws={"size": 8},cmap='viridis')
plt.show()

# %%
mask = np.zeros_like(df_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(df_corr,annot=True,mask=mask,cmap='viridis',annot_kws={"size": 8},linewidths=0.5)
plt.ylim(df_corr.shape[1],0);
plt.show()

# %%
df_practice = sns.load_dataset('iris')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 14            5.8          4.0           1.2          0.2      setosa
# 98            5.1          2.5           3.0          1.1  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 16            5.4          3.9           1.3          0.4      setosa
# 131           7.9          3.8           6.4          2.0   virginica

# %%
df_practice_corr = df_practice.corr(method='pearson')
mask = np.zeros_like(df_practice_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(df_practice_corr,annot=True,mask=mask,cmap='viridis',annot_kws={"size": 8},linewidths=0.5)
plt.ylim(df_corr.shape[1],0);
plt.show()

# %%
df = sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_pivot = pd.pivot_table(data=df, index='month', columns='year', values='passengers')
df_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
fig, axes = plt.subplots(figsize=(10,7))
sns.heatmap(data=df_pivot, annot=True, fmt=".0f", linewidths=.5, cmap='icefire')
plt.show()

# %%
np.random.seed(seed=1)
x= np.linspace(start=0,stop=10,num=50)
df = pd.DataFrame(data={"Demand":np.random.randn(50) + 5,
                        "Margin":np.sin(3*x),
                        "UserClicks":15 + np.cos(2*x) * x,
})

df.head(3)
# Out:
#      Demand    Margin  UserClicks
# 0  6.624345  0.000000   15.000000
# 1  4.388244  0.574706   15.187317
# 2  4.471828  0.940633   15.279552

# %%
fig, axes = plt.subplots(figsize=(10,5))
sns.lineplot(data=df)
plt.show()

# %%
df = sns.load_dataset('penguins')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
sns.countplot(data=df, x="species")
plt.show()

# %%
sns.countplot(data=df, x="species", hue='island')
plt.show()

# %%
df.groupby(['species','island']).size().unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
df_practice = sns.load_dataset('tips')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
sns.displot(df_practice, x='day', hue='time', multiple='stack')
plt.show()
