# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
df = sns.load_dataset('penguins')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
sns.set_theme(style="whitegrid")
sns.histplot(data=df, x='bill_length_mm')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot(data=df[['bill_length_mm','bill_depth_mm']])
plt.show()

# %%
sns.histplot(data=df, kde=True, x='bill_length_mm')
plt.show()

# %%
sns.histplot(data=df, kde=True, x='bill_length_mm', hue='species')
plt.show()

# %%
df_practice = sns.load_dataset('iris')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 14           5.8          4.0           1.2          0.2      setosa
# 98           5.1          2.5           3.0          1.1  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor

# %%
sns.set_theme(style="whitegrid")
sns.histplot(data=df_practice[['sepal_length','species']], kde=True)
plt.show()

# %%
sns.displot(data=df, x="flipper_length_mm")
plt.show()

# %%
sns.displot(df, x="flipper_length_mm", col="species")
plt.show()

# %%
 sns.displot(df, x="flipper_length_mm", col="species", row="sex")
 plt.show()

# %%
 sns.displot(df, x="flipper_length_mm", col="species", row="sex", hue='island')
 plt.show()

# %%
df_practice = sns.load_dataset('tips')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
 sns.displot(df_practice, x="total_bill", col="day", row="time")
 plt.show()

# %%
df = sns.load_dataset('tips')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
fig,ax = plt.subplots(figsize =(8,6))
sns.kdeplot(data=df.filter(['tip','total_bill'], axis=1),fill=True)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize =(11,6))

sns.kdeplot(data=df, x='tip',hue='sex',ax=axes[0,0],fill=True,  palette='Set1')
sns.kdeplot(data=df, x='tip',hue='time',ax=axes[0,1],fill=True,  palette='Set1')
sns.kdeplot(data=df, x='tip',hue='day',ax=axes[1,0],fill=True,  palette='Set1')
sns.kdeplot(data=df, x='tip',hue='size',ax=axes[1,1],fill=True, palette='Set1')

plt.tight_layout()
plt.show()
# Out:
# /workspace/data-analytics/venv/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
df_practice = sns.load_dataset('iris')
df_practice = df_practice.sample(n=50, random_state=1)
df.head(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
fig, axes = plt.subplots(2, figsize =(11,6))

sns.kdeplot(data=df_practice, x='sepal_length',hue='species',ax=axes[0],fill=True,  palette='Set1')
sns.kdeplot(data=df_practice, x='sepal_width',hue='species',ax=axes[1],fill=True,  palette='Set1')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2

# %%
sns.boxplot(data=df)
plt.show()

# %%
sns.boxplot(data=df, x='size', y='tip')
plt.show()

# %%
sns.boxplot(data=df, x="size", y="tip", hue="time")
plt.show()

# %%
df_practice = sns.load_dataset('iris')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 14           5.8          4.0           1.2          0.2      setosa
# 98           5.1          2.5           3.0          1.1  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor

# %%
sns.boxplot(data=df_practice, x="species", y="sepal_length")
plt.show()

# %%
sns.swarmplot(data=df, x='size', y='tip')
plt.show()

# %%
sns.swarmplot(data=df, x='size', y='tip', hue='time', dodge=True)
plt.show()

# %%
x, y, hue = 'size', 'tip', 'time'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

sns.boxplot(data=df, x=x, y=y, hue=hue, ax=axes[0])
sns.swarmplot(data=df, x=x, y=y, hue=hue, dodge=True, ax=axes[1])
plt.show()

# %%
df_practice = sns.load_dataset('penguins')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
x, y, hue = 'island', 'bill_length_mm', 'species'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

sns.boxplot(data=df_practice, x=x, y=y, hue=hue, ax=axes[0])
sns.swarmplot(data=df_practice, x=x, y=y, hue=hue, dodge=True, ax=axes[1])
plt.show()
