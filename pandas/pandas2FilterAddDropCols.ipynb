# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
df = pd.DataFrame(data=np.random.randn(5,4),
                  index=['A', 'B', 'C', 'D', 'E'],  
                  columns=['Col1', 'Col2', 'Col3', 'Col4']
                  )
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['Col1']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: Col1, dtype: float64

# %%
type(df['Col1'])
# Out:
# pandas.core.series.Series

# %%
df[['Col1']]
# Out:
#        Col1
# A  2.706850
# B  0.651118
# C -2.018168
# D  0.188695
# E  0.190794

# %%
type(df[['Col1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Col1','Col4']]
# Out:
#        Col1      Col4
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df[['Col1','Col2']]
# Out:
#        Col1      Col2
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df.filter(['Col1'])
# Out:
#        Col1
# A  2.706850
# B  0.651118
# C -2.018168
# D  0.188695
# E  0.190794

# %%
df.filter(['Col1','Col3'],axis=1)
# Out:
#        Col1      Col3
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df.filter(['Col1','Col3'],axis=1)
# Out:
#        Col1      Col3
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df['Col5'] = df['Col1'] + df['Col3']
df
# Out:
#        Col1      Col2      Col3      Col4      Col5
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop(labels=['Col5'],axis=1)
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#        Col1      Col2      Col3      Col4      Col5
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop(labels=['Col5'],axis=1,inplace=True) # in place overwrites exist and the col5 is dripped
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['Col5'] = df['Col1'] + df['Col3']
df
# Out:
#        Col1      Col2      Col3      Col4      Col5
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df = df.drop(labels=['Col5'],axis=1) # second way to drop a col
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop(labels=['A','E'],axis=0)
# Out:
#        Col1      Col2      Col3      Col4
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df=df.drop(labels=['B','C'],axis=0)
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
