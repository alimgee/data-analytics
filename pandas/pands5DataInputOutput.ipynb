# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/flights.csv')
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/flights.csv',
                 index_col=['year'])
df
# Out:
#           month  passengers
# year
# 1949    January         112
# 1949   February         118
# 1949      March         132
# 1949      April         129
# 1949        May         121
# ...         ...         ...
# 1960     August         606
# 1960  September         508
# 1960    October         461
# 1960   November         390
# 1960   December         432
#
# [144 rows x 2 columns]

# %%
df.to_csv('csv_example.csv')

# %%
# !pwd
# Out:
# /workspace/data-analytics/pandas

# %%
! ls
# Out:
# csv_example.csv			pandas3SelectData.ipynb
# csv_penguin.csv			pandas4MultiIndex.ipynb
# pandas1SeriesDataframe.ipynb	pands5DataInputOutput.ipynb
# pandas2FilterAddDropCols.ipynb

# %%
df_example = pd.read_csv('csv_example.csv')
df_example
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
# write your code here
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/penguins.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# write your code here
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/penguins.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.to_csv('csv_penguin.csv')

# %%
search = pd.read_html('https://en.wikipedia.org/wiki/FIFA_World_Cup')

# %%
search
# Out:
# [                                   0                                  1
#  0                                NaN                                NaN
#  1                            Founded                 1930; 92 years ago
#  2                             Region               International (FIFA)
#  3                    Number of teams                        32 (finals)
#  4                  Current champions                 France (2nd title)
#  5            Most successful team(s)                  Brazil (5 titles)
#  6            Television broadcasters               List of broadcasters
#  7                            Website                   Official website
#  8  2022 FIFA World Cup qualification  2022 FIFA World Cup qualification,
#                                                     0  \
#  0                France, the current world champions
#  1                                        Tournaments
#  2  1930 1934 1938 1950 1954 1958 1962 1966 1970 1...
#
# ...

# %%
df = search[3]
df
# Out:
#        Year              Hosts Venues/Cities Totalattendance Matches  \
#        Year              Hosts Venues/Cities Totalattendance Matches
# 0      1930            Uruguay           3/1          590549      18
# 1      1934              Italy           8/8          363000      17
# 2      1938             France          10/9          375700      18
# 3      1950             Brazil           6/6         1045246      22
# 4      1954        Switzerland           6/6          768607      26
# 5      1958             Sweden         12/12          819810      35
# 6      1962              Chile           4/4          893172      32
# 7      1966            England           8/7         1563135      32
# 8      1970             Mexico           5/5         1603975      32
# 9      1974       West Germany           9/9         1865753      38
# 10     1978          Argentina           6/5         1545791      38
# 11     1982              Spain         17/14         2109723      52
# ...

# %%
df = search[2]

df
# Out:
#   Confederation  Total                                      (Hosts) Years
# 0           AFC      2                                         2002, 2022
# 1           CAF      1                                               2010
# 2      CONCACAF      4                             1970, 1986, 1994, 2026
# 3      CONMEBOL      5                       1930, 1950, 1962, 1978, 2014
# 4           OFC      0                                                NaN
# 5          UEFA     11  1934, 1938, 1954, 1958, 1966, 1974, 1982, 1990...
