# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # used for loading datasets

# %%
df = sns.load_dataset('penguins')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
categorical_count = df['species'].value_counts()
categorical_count
# Out:
# Adelie       24
# Gentoo       19
# Chinstrap     7
# Name: species, dtype: int64

# %%
plt.bar(x=categorical_count.index, height=categorical_count)
plt.show()

# %%
categorical_count = df['species'].value_counts()
plt.barh(y=categorical_count.index, width=categorical_count)
plt.show()

# %%
categorical_count = df['species'].value_counts()
plt.barh(y=categorical_count.index, width=categorical_count)
plt.show()

# %%
df_practice = sns.load_dataset('tips')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4

# %%
categorical_count = df_practice.value_counts('sex',normalize=True)
plt.pie(x=categorical_count, labels=categorical_count.index)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
z = np.linspace(0, 5, 500)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)
ax.plot3D(x, y, z)
plt.show()

# %%
df = sns.load_dataset('penguins')
df = df.sample(n=50, random_state=1)
df.head(3)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection='3d')

x = df['bill_depth_mm']
y = df['bill_length_mm']
z = df['flipper_length_mm']

ax.scatter(x, y, z)
plt.show()

# %%
df_practice = sns.load_dataset('tips')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4

# %%
fig = plt.figure(figsize=(15,9))
ax = plt.axes(projection='3d')

x = df_practice['total_bill']
y = df_practice['tip']
z = df_practice['size']

ax.scatter(x, y, z)
plt.show()

# %%
image_url = "https://learn.codeinstitute.net/static/ci-theme/images/logo.png"
image = plt.imread(image_url, format='png')
# Out:
# /tmp/ipykernel_2017/1307626024.py:2: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
#   image = plt.imread(image_url, format='png')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image)
plt.show()
